# %%
# %matplotlib inline

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import plotly.express as px
from scipy.stats import linregress
import plotly.graph_objects as go

# %%
# Display the data
life_expectancy = Path("output/csv/life_expectancy.csv")
life_expectancy_df = pd.read_csv(life_expectancy)
gdp_file = Path("output/csv/final_gdp.csv")
gdp_file_df = pd.read_csv(gdp_file)
health_expend = Path("output/csv/OECD_Health_Expenditure.csv")
health_expend_df = pd.read_csv(health_expend)
world_bank = Path("output/csv/cleaned_world_bank_dataset.csv")
world_bank_df = pd.read_csv(world_bank)
gbp_data = Path("output/csv/cleaned_gbp_dataset.csv")
gbp_data_df = pd.read_csv(gbp_data)
display(life_expectancy_df)
display(gdp_file_df)
display(health_expend_df)
display(world_bank_df)
display(gbp_data_df)
# Out:
#                          Country  Year  Life Expectancy  Population  \
# 0                          WORLD  1950             46.5     2499322
# 1                          WORLD  1951             47.1     2543130
# 2                          WORLD  1952             48.2     2590271
# 3                          WORLD  1953             48.8     2640279
# 4                          WORLD  1954             49.6     2691979
# ...                          ...   ...              ...         ...
# 20587  Wallis and Futuna Islands  2017             77.5          12
# 20588  Wallis and Futuna Islands  2018             77.9          12
# 20589  Wallis and Futuna Islands  2019             79.6          12
# 20590  Wallis and Futuna Islands  2020             78.8          12
# 20591  Wallis and Futuna Islands  2021             78.4          12
#
#                Type  Male Population, as of 1 July (thousands)  \
# 0             World                                  1245363.0
# 1             World                                  1267473.0
# 2             World                                  1291400.0
# 3             World                                  1316659.0
# 4             World                                  1342923.0
# ...             ...                                        ...
# 20587  Country/Area                                        6.0
# 20588  Country/Area                                        6.0
# 20589  Country/Area                                        6.0
# 20590  Country/Area                                        6.0
# 20591  Country/Area                                        6.0
#
#        Female Population, as of 1 July (thousands)  \
# 0                                        1253959.0
# 1                                        1275657.0
# 2                                        1298871.0
# 3                                        1323620.0
# 4                                        1349056.0
# ...                                            ...
# 20587                                          6.0
# 20588                                          6.0
# 20589                                          6.0
# 20590                                          6.0
# 20591                                          6.0
#
#        Male Life Expectancy at Birth (years)  \
# 0                                       44.6
# 1                                       45.4
# 2                                       46.6
# 3                                       47.2
# 4                                       48.0
# ...                                      ...
# 20587                                   77.1
# 20588                                   76.4
# 20589                                   78.6
# 20590                                   77.7
# 20591                                   77.1
#
#        Female Life Expectancy at Birth (years)
# 0                                         48.4
# 1                                         49.0
# 2                                         49.9
# 3                                         50.4
# 4                                         51.2
# ...                                        ...
# 20587                                     78.0
# 20588                                     79.5
# 20589                                     80.6
# 20590                                     79.8
# 20591                                     79.9
#
# [20592 rows x 9 columns]
#        countrycode      Country                     Region  Year  \
# 0              AFG  Afghanistan  South and South East Asia     1
# 1              AFG  Afghanistan  South and South East Asia   730
# 2              AFG  Afghanistan  South and South East Asia  1000
# 3              AFG  Afghanistan  South and South East Asia  1090
# 4              AFG  Afghanistan  South and South East Asia  1150
# ...            ...          ...                        ...   ...
# 131139         ZWE     Zimbabwe         Sub Saharan Africa  2018
# 131140         ZWE     Zimbabwe         Sub Saharan Africa  2019
# 131141         ZWE     Zimbabwe         Sub Saharan Africa  2020
# 131142         ZWE     Zimbabwe         Sub Saharan Africa  2021
# 131143         ZWE     Zimbabwe         Sub Saharan Africa  2022
#
#         GDP per Capita      pop
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# ...                ...      ...
# 131139          1900.0  14097.0
# 131140          1753.0  14345.0
# 131141          1586.0  14615.0
# 131142          1687.0  14900.0
# 131143          1704.0  15205.0
#
# [131144 rows x 6 columns]
#       Country      Measure    Unit of Measure  Year  Health Expenditure
# 0      Brazil  Expenditure  Percentage of GDP  2005               8.035
# 1       India  Expenditure  Percentage of GDP  2003               4.134
# 2       India  Expenditure  Percentage of GDP  2002               4.373
# 3     Belgium  Expenditure  Percentage of GDP  2013              10.575
# 4       India  Expenditure  Percentage of GDP  2009               3.594
# ...       ...          ...                ...   ...                 ...
# 1856   Brazil  Expenditure  Percentage of GDP  2010               7.945
# 1857   Brazil  Expenditure  Percentage of GDP  2009               8.395
# 1858   Brazil  Expenditure  Percentage of GDP  2008               8.011
# 1859   Brazil  Expenditure  Percentage of GDP  2007               8.202
# 1860   Brazil  Expenditure  Percentage of GDP  2006               8.250
#
# [1861 rows x 5 columns]
#        country name country code  year  \
# 0         Australia          AUS  1960
# 1         Australia          AUS  1961
# 2         Australia          AUS  1962
# 3         Australia          AUS  1963
# 4         Australia          AUS  1964
# ...             ...          ...   ...
# 2171  United States          USA  2019
# 2172  United States          USA  2020
# 2173  United States          USA  2021
# 2174  United States          USA  2022
# 2175  United States          USA  2023
#
#       adjusted savings: education expenditure (current us$)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2171                                       9.645020e+11
# 2172                                       9.515541e+11
# 2173                                       1.046599e+12
# 2174                                                NaN
# 2175                                                NaN
#
#       current health expenditure (% of gdp)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 2171                              16.665806
# 2172                              18.756220
# 2173                              17.362568
# 2174                              16.571152
# 2175                                    NaN
#
#       domestic credit to private sector (% of gdp)  gdp (constant 2015 us$)  \
# 0                                        19.116355             2.045527e+11
# 1                                        17.629453             2.096310e+11
# 2                                        18.647403             2.123441e+11
# 3                                        19.283486             2.255442e+11
# 4                                        20.111524             2.412882e+11
# ...                                            ...                      ...
# 2171                                    194.903442             2.013669e+13
# 2172                                    218.654623             1.969097e+13
# 2173                                    221.129332             2.083309e+13
# 2174                                    189.793750             2.123631e+13
# 2175                                    194.946427             2.177628e+13
#
#       labor force with advanced education (% of total working-age population with advanced education)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2171                                             73.125
# 2172                                             71.640
# 2173                                             71.375
# 2174                                             71.780
# 2175                                             71.866
#
#       labor force with intermediate education (% of total working-age population with intermediate education)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2171                                             57.359
# 2172                                             55.474
# 2173                                             55.481
# 2174                                             56.076
# 2175                                             56.415
#
#       labor force with basic education (% of total working-age population with basic education)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2171                                             42.186
# 2172                                             41.018
# 2173                                             41.762
# 2174                                             42.572
# 2175                                             44.161
#
#       market capitalization of listed domestic companies (% of gdp)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2171                                         158.380660
# 2172                                         194.953615
# 2173                                         205.766188
# 2174                                         156.532828
# 2175                                                NaN
#
#       military expenditure (% of gdp)  \
# 0                            2.369545
# 1                            2.415140
# 2                            2.363695
# 3                            2.446635
# 4                            2.648243
# ...                               ...
# 2171                         3.434568
# 2172                         3.696010
# 2173                         3.457977
# 2174                         3.454920
# 2175                              NaN
#
#       out-of-pocket expenditure (% of current health expenditure)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2171                                          11.308306
# 2172                                           9.931046
# 2173                                          10.700169
# 2174                                                NaN
# 2175                                                NaN
#
#       research and development expenditure (% of gdp)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 2171                                          3.17049
# 2172                                          3.46777
# 2173                                          3.45705
# 2174                                              NaN
# 2175                                              NaN
#
#       stocks traded, total value (% of gdp)
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 2171                             168.865978
# 2172                             192.686572
# 2173                             194.431149
# 2174                             172.139937
# 2175                                    NaN
#
# [2176 rows x 15 columns]
#                       location  year  Alcohol use disorders  \
# 0                    Australia  1980             224.640827
# 1                    Australia  1981             201.375438
# 2                    Australia  1982             202.209596
# 3                    Australia  1983             199.414824
# 4                    Australia  1984             219.721324
# ...                        ...   ...                    ...
# 1507  United States of America  2017           16447.213615
# 1508  United States of America  2018           16881.662205
# 1509  United States of America  2019           17468.451200
# 1510  United States of America  2020           17342.695548
# 1511  United States of America  2021           17300.933653
#
#       Cardiovascular diseases  Diabetes mellitus  \
# 0                53175.420093        1653.097958
# 1                53519.112787        1686.202270
# 2                53790.303828        1660.396011
# 3                52886.554707        1725.082632
# 4                53371.722621        1850.495453
# ...                       ...                ...
# 1507            870014.594907       68023.019190
# 1508            874704.259786       69243.158362
# 1509            880826.245325       71201.256403
# 1510            887324.919965       72130.507793
# 1511            905653.064300       74017.278108
#
#       Liver cancer due to alcohol use  Motor vehicle road injuries  \
# 0                           74.913434                  2254.190078
# 1                           94.786014                  2045.041012
# 2                           89.814276                  2108.075231
# 3                           94.982144                  1954.825946
# 4                          103.952826                  1954.861215
# ...                               ...                          ...
# 1507                      6521.645578                 29072.563739
# 1508                      6842.077243                 28301.510359
# 1509                      7109.802427                 27881.005935
# 1510                      7371.063919                 27682.805304
# 1511                      7405.873087                 27577.240531
#
#       Opioid use disorders  Police conflict and executions  Road injuries  \
# 0               127.520326                        2.108937    3650.419375
# 1               137.103994                        2.511270    3546.024686
# 2               167.695152                        2.992388    3456.007451
# 3               197.186626                        3.760895    3178.641691
# 4               224.345417                        4.648462    3152.437840
# ...                    ...                             ...            ...
# 1507          45323.057374                     1182.453872   43311.226390
# 1508          47371.011599                     1166.479287   42451.281976
# 1509          50031.617474                     1174.843121   41975.079605
# 1510          52561.060543                     1118.220151   41612.775573
# 1511          55451.968230                     1089.792998   41371.804169
#
#          Self-harm  Tracheal, bronchus, and lung cancer
# 0      1746.699803                          5293.914876
# 1      1766.705496                          5405.440354
# 2      1804.678951                          5527.492269
# 3      1814.903926                          5614.889254
# 4      1884.354769                          5730.540582
# ...            ...                                  ...
# 1507  51264.771154                        172205.186019
# 1508  51762.833329                        168804.579530
# 1509  51357.018236                        167925.872553
# 1510  50982.047075                        170317.701686
# 1511  50715.835465                        175479.668947
#
# [1512 rows x 12 columns]

# %%
# Merging Life Expentancy and GDP file on Country and Year
combined_le_gdp = pd.merge(life_expectancy_df, gdp_file_df, on=["Country","Year"] , how="left") 
combined_le_gdp
# Out:
#                          Country  Year  Life Expectancy  Population  \
# 0                          WORLD  1950             46.5     2499322
# 1                          WORLD  1951             47.1     2543130
# 2                          WORLD  1952             48.2     2590271
# 3                          WORLD  1953             48.8     2640279
# 4                          WORLD  1954             49.6     2691979
# ...                          ...   ...              ...         ...
# 20587  Wallis and Futuna Islands  2017             77.5          12
# 20588  Wallis and Futuna Islands  2018             77.9          12
# 20589  Wallis and Futuna Islands  2019             79.6          12
# 20590  Wallis and Futuna Islands  2020             78.8          12
# 20591  Wallis and Futuna Islands  2021             78.4          12
#
#                Type  Male Population, as of 1 July (thousands)  \
# 0             World                                  1245363.0
# 1             World                                  1267473.0
# 2             World                                  1291400.0
# 3             World                                  1316659.0
# 4             World                                  1342923.0
# ...             ...                                        ...
# 20587  Country/Area                                        6.0
# 20588  Country/Area                                        6.0
# 20589  Country/Area                                        6.0
# 20590  Country/Area                                        6.0
# 20591  Country/Area                                        6.0
#
#        Female Population, as of 1 July (thousands)  \
# 0                                        1253959.0
# 1                                        1275657.0
# 2                                        1298871.0
# 3                                        1323620.0
# 4                                        1349056.0
# ...                                            ...
# 20587                                          6.0
# 20588                                          6.0
# 20589                                          6.0
# 20590                                          6.0
# 20591                                          6.0
#
#        Male Life Expectancy at Birth (years)  \
# 0                                       44.6
# 1                                       45.4
# 2                                       46.6
# 3                                       47.2
# 4                                       48.0
# ...                                      ...
# 20587                                   77.1
# 20588                                   76.4
# 20589                                   78.6
# 20590                                   77.7
# 20591                                   77.1
#
#        Female Life Expectancy at Birth (years) countrycode Region  \
# 0                                         48.4         NaN    NaN
# 1                                         49.0         NaN    NaN
# 2                                         49.9         NaN    NaN
# 3                                         50.4         NaN    NaN
# 4                                         51.2         NaN    NaN
# ...                                        ...         ...    ...
# 20587                                     78.0         NaN    NaN
# 20588                                     79.5         NaN    NaN
# 20589                                     80.6         NaN    NaN
# 20590                                     79.8         NaN    NaN
# 20591                                     79.9         NaN    NaN
#
#        GDP per Capita  pop
# 0                 NaN  NaN
# 1                 NaN  NaN
# 2                 NaN  NaN
# 3                 NaN  NaN
# 4                 NaN  NaN
# ...               ...  ...
# 20587             NaN  NaN
# 20588             NaN  NaN
# 20589             NaN  NaN
# 20590             NaN  NaN
# 20591             NaN  NaN
#
# [20592 rows x 13 columns]

# %%
# Merging Life Expentancy,GDP file with Health Expenditure file on Country and Year
combined_le_gdp_he = pd.merge(combined_le_gdp, health_expend_df, on=["Country","Year"] , how="left") 
combined_le_gdp_he
# Out:
#                          Country  Year  Life Expectancy  Population  \
# 0                          WORLD  1950             46.5     2499322
# 1                          WORLD  1951             47.1     2543130
# 2                          WORLD  1952             48.2     2590271
# 3                          WORLD  1953             48.8     2640279
# 4                          WORLD  1954             49.6     2691979
# ...                          ...   ...              ...         ...
# 20587  Wallis and Futuna Islands  2017             77.5          12
# 20588  Wallis and Futuna Islands  2018             77.9          12
# 20589  Wallis and Futuna Islands  2019             79.6          12
# 20590  Wallis and Futuna Islands  2020             78.8          12
# 20591  Wallis and Futuna Islands  2021             78.4          12
#
#                Type  Male Population, as of 1 July (thousands)  \
# 0             World                                  1245363.0
# 1             World                                  1267473.0
# 2             World                                  1291400.0
# 3             World                                  1316659.0
# 4             World                                  1342923.0
# ...             ...                                        ...
# 20587  Country/Area                                        6.0
# 20588  Country/Area                                        6.0
# 20589  Country/Area                                        6.0
# 20590  Country/Area                                        6.0
# 20591  Country/Area                                        6.0
#
#        Female Population, as of 1 July (thousands)  \
# 0                                        1253959.0
# 1                                        1275657.0
# 2                                        1298871.0
# 3                                        1323620.0
# 4                                        1349056.0
# ...                                            ...
# 20587                                          6.0
# 20588                                          6.0
# 20589                                          6.0
# 20590                                          6.0
# 20591                                          6.0
#
#        Male Life Expectancy at Birth (years)  \
# 0                                       44.6
# 1                                       45.4
# 2                                       46.6
# 3                                       47.2
# 4                                       48.0
# ...                                      ...
# 20587                                   77.1
# 20588                                   76.4
# 20589                                   78.6
# 20590                                   77.7
# 20591                                   77.1
#
#        Female Life Expectancy at Birth (years) countrycode Region  \
# 0                                         48.4         NaN    NaN
# 1                                         49.0         NaN    NaN
# 2                                         49.9         NaN    NaN
# 3                                         50.4         NaN    NaN
# 4                                         51.2         NaN    NaN
# ...                                        ...         ...    ...
# 20587                                     78.0         NaN    NaN
# 20588                                     79.5         NaN    NaN
# 20589                                     80.6         NaN    NaN
# 20590                                     79.8         NaN    NaN
# 20591                                     79.9         NaN    NaN
#
#        GDP per Capita  pop Measure Unit of Measure  Health Expenditure
# 0                 NaN  NaN     NaN             NaN                 NaN
# 1                 NaN  NaN     NaN             NaN                 NaN
# 2                 NaN  NaN     NaN             NaN                 NaN
# 3                 NaN  NaN     NaN             NaN                 NaN
# 4                 NaN  NaN     NaN             NaN                 NaN
# ...               ...  ...     ...             ...                 ...
# 20587             NaN  NaN     NaN             NaN                 NaN
# 20588             NaN  NaN     NaN             NaN                 NaN
# 20589             NaN  NaN     NaN             NaN                 NaN
# 20590             NaN  NaN     NaN             NaN                 NaN
# 20591             NaN  NaN     NaN             NaN                 NaN
#
# [20592 rows x 16 columns]

# %%
# Rename useful columns before merging
renamed_wb = world_bank_df.rename(columns={"country name":"Country", "year":"Year"})

# Merging Life Expentancy,GDP,Health Expenditure file with world_bank_df on Country and Year
combined_le_gdp_he_wb = pd.merge(combined_le_gdp_he, renamed_wb, on=["Country","Year"] , how="left") 
combined_le_gdp_he_wb
# Out:
#                          Country  Year  Life Expectancy  Population  \
# 0                          WORLD  1950             46.5     2499322
# 1                          WORLD  1951             47.1     2543130
# 2                          WORLD  1952             48.2     2590271
# 3                          WORLD  1953             48.8     2640279
# 4                          WORLD  1954             49.6     2691979
# ...                          ...   ...              ...         ...
# 20587  Wallis and Futuna Islands  2017             77.5          12
# 20588  Wallis and Futuna Islands  2018             77.9          12
# 20589  Wallis and Futuna Islands  2019             79.6          12
# 20590  Wallis and Futuna Islands  2020             78.8          12
# 20591  Wallis and Futuna Islands  2021             78.4          12
#
#                Type  Male Population, as of 1 July (thousands)  \
# 0             World                                  1245363.0
# 1             World                                  1267473.0
# 2             World                                  1291400.0
# 3             World                                  1316659.0
# 4             World                                  1342923.0
# ...             ...                                        ...
# 20587  Country/Area                                        6.0
# 20588  Country/Area                                        6.0
# 20589  Country/Area                                        6.0
# 20590  Country/Area                                        6.0
# 20591  Country/Area                                        6.0
#
#        Female Population, as of 1 July (thousands)  \
# 0                                        1253959.0
# 1                                        1275657.0
# 2                                        1298871.0
# 3                                        1323620.0
# 4                                        1349056.0
# ...                                            ...
# 20587                                          6.0
# 20588                                          6.0
# 20589                                          6.0
# 20590                                          6.0
# 20591                                          6.0
#
#        Male Life Expectancy at Birth (years)  \
# 0                                       44.6
# 1                                       45.4
# 2                                       46.6
# 3                                       47.2
# 4                                       48.0
# ...                                      ...
# 20587                                   77.1
# 20588                                   76.4
# 20589                                   78.6
# 20590                                   77.7
# 20591                                   77.1
#
#        Female Life Expectancy at Birth (years) countrycode  ...  \
# 0                                         48.4         NaN  ...
# 1                                         49.0         NaN  ...
# 2                                         49.9         NaN  ...
# 3                                         50.4         NaN  ...
# 4                                         51.2         NaN  ...
# ...                                        ...         ...  ...
# 20587                                     78.0         NaN  ...
# 20588                                     79.5         NaN  ...
# 20589                                     80.6         NaN  ...
# 20590                                     79.8         NaN  ...
# 20591                                     79.9         NaN  ...
#
#       domestic credit to private sector (% of gdp)  gdp (constant 2015 us$)  \
# 0                                              NaN                      NaN
# 1                                              NaN                      NaN
# 2                                              NaN                      NaN
# 3                                              NaN                      NaN
# 4                                              NaN                      NaN
# ...                                            ...                      ...
# 20587                                          NaN                      NaN
# 20588                                          NaN                      NaN
# 20589                                          NaN                      NaN
# 20590                                          NaN                      NaN
# 20591                                          NaN                      NaN
#
#        labor force with advanced education (% of total working-age population with advanced education)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20587                                                NaN
# 20588                                                NaN
# 20589                                                NaN
# 20590                                                NaN
# 20591                                                NaN
#
#       labor force with intermediate education (% of total working-age population with intermediate education)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20587                                                NaN
# 20588                                                NaN
# 20589                                                NaN
# 20590                                                NaN
# 20591                                                NaN
#
#       labor force with basic education (% of total working-age population with basic education)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20587                                                NaN
# 20588                                                NaN
# 20589                                                NaN
# 20590                                                NaN
# 20591                                                NaN
#
#        market capitalization of listed domestic companies (% of gdp)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20587                                                NaN
# 20588                                                NaN
# 20589                                                NaN
# 20590                                                NaN
# 20591                                                NaN
#
#       military expenditure (% of gdp)  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 20587                             NaN
# 20588                             NaN
# 20589                             NaN
# 20590                             NaN
# 20591                             NaN
#
#        out-of-pocket expenditure (% of current health expenditure)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20587                                                NaN
# 20588                                                NaN
# 20589                                                NaN
# 20590                                                NaN
# 20591                                                NaN
#
#        research and development expenditure (% of gdp)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 20587                                              NaN
# 20588                                              NaN
# 20589                                              NaN
# 20590                                              NaN
# 20591                                              NaN
#
#        stocks traded, total value (% of gdp)
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 20587                                    NaN
# 20588                                    NaN
# 20589                                    NaN
# 20590                                    NaN
# 20591                                    NaN
#
# [20592 rows x 29 columns]

# %%
# Rename useful columns before merging
renamed_gbp = gbp_data_df.rename(columns={"location":"Country", "year":"Year"})
renamed_gbp

# Merging Life Expentancy,GDP,Health Expenditure, world_bank_df file with gbp_data_df on Country and Year to get the FINAL FILE
combined_df = pd.merge(combined_le_gdp_he_wb, renamed_wb, on=["Country","Year"] , how="left") 
combined_df
# Out:
#                          Country  Year  Life Expectancy  Population  \
# 0                          WORLD  1950             46.5     2499322
# 1                          WORLD  1951             47.1     2543130
# 2                          WORLD  1952             48.2     2590271
# 3                          WORLD  1953             48.8     2640279
# 4                          WORLD  1954             49.6     2691979
# ...                          ...   ...              ...         ...
# 20587  Wallis and Futuna Islands  2017             77.5          12
# 20588  Wallis and Futuna Islands  2018             77.9          12
# 20589  Wallis and Futuna Islands  2019             79.6          12
# 20590  Wallis and Futuna Islands  2020             78.8          12
# 20591  Wallis and Futuna Islands  2021             78.4          12
#
#                Type  Male Population, as of 1 July (thousands)  \
# 0             World                                  1245363.0
# 1             World                                  1267473.0
# 2             World                                  1291400.0
# 3             World                                  1316659.0
# 4             World                                  1342923.0
# ...             ...                                        ...
# 20587  Country/Area                                        6.0
# 20588  Country/Area                                        6.0
# 20589  Country/Area                                        6.0
# 20590  Country/Area                                        6.0
# 20591  Country/Area                                        6.0
#
#        Female Population, as of 1 July (thousands)  \
# 0                                        1253959.0
# 1                                        1275657.0
# 2                                        1298871.0
# 3                                        1323620.0
# 4                                        1349056.0
# ...                                            ...
# 20587                                          6.0
# 20588                                          6.0
# 20589                                          6.0
# 20590                                          6.0
# 20591                                          6.0
#
#        Male Life Expectancy at Birth (years)  \
# 0                                       44.6
# 1                                       45.4
# 2                                       46.6
# 3                                       47.2
# 4                                       48.0
# ...                                      ...
# 20587                                   77.1
# 20588                                   76.4
# 20589                                   78.6
# 20590                                   77.7
# 20591                                   77.1
#
#        Female Life Expectancy at Birth (years) countrycode  ...  \
# 0                                         48.4         NaN  ...
# 1                                         49.0         NaN  ...
# 2                                         49.9         NaN  ...
# 3                                         50.4         NaN  ...
# 4                                         51.2         NaN  ...
# ...                                        ...         ...  ...
# 20587                                     78.0         NaN  ...
# 20588                                     79.5         NaN  ...
# 20589                                     80.6         NaN  ...
# 20590                                     79.8         NaN  ...
# 20591                                     79.9         NaN  ...
#
#       domestic credit to private sector (% of gdp)_y  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 20587                                            NaN
# 20588                                            NaN
# 20589                                            NaN
# 20590                                            NaN
# 20591                                            NaN
#
#        gdp (constant 2015 us$)_y  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 20587                        NaN
# 20588                        NaN
# 20589                        NaN
# 20590                        NaN
# 20591                        NaN
#
#        labor force with advanced education (% of total working-age population with advanced education)_y  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20587                                                NaN
# 20588                                                NaN
# 20589                                                NaN
# 20590                                                NaN
# 20591                                                NaN
#
#       labor force with intermediate education (% of total working-age population with intermediate education)_y  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20587                                                NaN
# 20588                                                NaN
# 20589                                                NaN
# 20590                                                NaN
# 20591                                                NaN
#
#       labor force with basic education (% of total working-age population with basic education)_y  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20587                                                NaN
# 20588                                                NaN
# 20589                                                NaN
# 20590                                                NaN
# 20591                                                NaN
#
#        market capitalization of listed domestic companies (% of gdp)_y  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20587                                                NaN
# 20588                                                NaN
# 20589                                                NaN
# 20590                                                NaN
# 20591                                                NaN
#
#       military expenditure (% of gdp)_y  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 20587                               NaN
# 20588                               NaN
# 20589                               NaN
# 20590                               NaN
# 20591                               NaN
#
#        out-of-pocket expenditure (% of current health expenditure)_y  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20587                                                NaN
# 20588                                                NaN
# 20589                                                NaN
# 20590                                                NaN
# 20591                                                NaN
#
#        research and development expenditure (% of gdp)_y  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20587                                                NaN
# 20588                                                NaN
# 20589                                                NaN
# 20590                                                NaN
# 20591                                                NaN
#
#        stocks traded, total value (% of gdp)_y
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 20587                                      NaN
# 20588                                      NaN
# 20589                                      NaN
# 20590                                      NaN
# 20591                                      NaN
#
# [20592 rows x 42 columns]

# %%
# Specify the file path where you want to save the CSV file
csv_file_path = '../output/csv/life_expectancy.csv'

# Write final_df to CSV
final_df.to_csv(csv_file_path, index=False)

print(f"DataFrame successfully written to {csv_file_path}")
